# %%
import numpy as np

# %%
lamost_true = "/home/arbiter/projects/Survey-invariant-generalization/src/inspection/model_inspection/lamost_true_reg.npy"

# %%
lamost_true_arr = np.load(lamost_true)

# %%
lamost_true_arr.shape
# Out:
# (19800, 3)

# %%
lamost_true_arr[:, 0]
# Out:
# array([-0.25493777,  0.34298408,  0.2331539 , ...,  0.51810884,
#         0.7111751 ,  0.40859374], shape=(19800,), dtype=float32)

# %%
a = ["1", "2", "3"]
b = ["cat", "dog", "pizza"]

for i, (name, value) in enumerate(zip(a, b)):
    print(i)
# Out:
# 0
# 1
# 2
