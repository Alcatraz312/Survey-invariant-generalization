# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from astropy.io import fits

import requests

# %%
with fits.open("/home/arbiter/projects/Survey-invariant-generalization/data/spec-55907-B90704_sp01-130.fits") as star_data:
    star_data.info()
# Out:
# Filename: /home/arbiter/projects/Survey-invariant-generalization/data/spec-55907-B90704_sp01-130.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  Flux          1 PrimaryHDU     127   (3909, 5)   float32

# %%
with fits.open("../../data/dr11_v2.0_LRS_stellar.fits") as lamost_data:
    lamost_data.info()

primary_header = lamost_data[0].header
secondary_header = lamost_data[1].header
secondary_header
# Out:
# Filename: ../../data/dr11_v2.0_LRS_stellar.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      11   ()
#   1                1 BinTableHDU    155   7898024R x 45C   [J, 32A, K, 19A, 10A, J, J, 40A, I, I, D, D, E, E, E, E, E, 20A, 20A, E, E, K, E, E, E, E, E, 25A, E, 10A, I, E, D, D, E, E, E, E, E, E, E, E, E, E, E]
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  342 / length of dimension 1
# NAXIS2  =              7898024 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   45 / number of table fields
# TTYPE1  = 'obsid   '
# TFORM1  = 'J       '
# TDISP1  = 'I8      '
# TTYPE2  = 'uid     '
# TFORM2  = '32A     '
# TDISP2  = 'A32     '
# TTYPE3  = 'gp_id   '
# ...

# %%
with fits.open("../../data/dr11_v2.0_LRS_stellar.fits") as lamost_data:
    secondary_data = lamost_data[1].data

secondary_data[4]

# %%
secondary_header
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 secondary_header
#
# NameError: name 'secondary_header' is not defined
