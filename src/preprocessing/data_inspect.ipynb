# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt

import h5py
import tqdm

# %matplotlib inline

# %%
sdss_data = h5py.File("/home/arbiter/projects/Survey-invariant-generalization/data/sdss_resampled.h5")

# %%
len(sdss_data.keys())
# Out:
# 21960

# %%
wavelength = sdss_data["1000-198-52643"]["wavelength_grid"][:]
flux = sdss_data["1000-198-52643"]["flux"][:]
snr = sdss_data["1000-198-52643"]["snr"][:]

# %%
plt.plot(wavelength, flux)
plt.grid()
plt.show()
